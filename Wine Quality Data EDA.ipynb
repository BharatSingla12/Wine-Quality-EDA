# %% [markdown]
# ## Importing packages and loading the data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('E:\Chrome Downloads\winequality-white.csv',sep=';')

# %% [markdown]
# ## Understanding the basic structure of data

# %%
# Get the sample of the data 
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1588            7.3              0.30         0.74           13.50      0.039
# 3869            6.2              0.22         0.30           12.40      0.054
# 2396            8.4              0.30         0.25           17.75      0.047
# 1936            9.2              0.27         0.34           10.50      0.043
# 4715            6.7              0.15         0.32            7.90      0.034
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1588                 46.0                 165.0  0.99820  3.02       0.40
# 3869                108.0                 152.0  0.99728  3.10       0.47
# 2396                 25.0                 218.0  1.00016  2.98       0.66
# 1936                 49.0                 228.0  0.99740  3.04       0.41
# 4715                 17.0                  81.0  0.99512  3.29       0.31
#
#       alcohol  quality
# 1588      8.7        5
# ...

# %%
# Get the shape and size of the data
print(f"The shape of the data is {df.shape} and the size is {df.size}.")
# Out:
# The shape of the data is (4898, 12) and the size is 58776.

# %%
# List of features 
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Get the info and describe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df[df.duplicated()].sort_values(by = 'fixed acidity').nunique()
# Out:
# fixed acidity            49
# volatile acidity         64
# citric acid              68
# residual sugar          216
# chlorides                74
# free sulfur dioxide      87
# total sulfur dioxide    178
# density                 417
# pH                       81
# sulphates                62
# alcohol                  61
# quality                   5
# dtype: int64

# %%
df['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
# Check the duplicate rows 
df.duplicated().sum()
# Out:
# 937

# %%
# Check the null values 
df.isnull().sum().sort_values(ascending = False)
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.plot(kind = 'box', figsize  = (10,20),subplots = True, vert=0, layout  = (12,1),sharex = False)
# Out:
# fixed acidity           AxesSubplot(0.01,0.929085;0.98x0.0609155)
# volatile acidity        AxesSubplot(0.01,0.855986;0.98x0.0609155)
# citric acid             AxesSubplot(0.01,0.782887;0.98x0.0609155)
# residual sugar          AxesSubplot(0.01,0.709789;0.98x0.0609155)
# chlorides                AxesSubplot(0.01,0.63669;0.98x0.0609155)
# free sulfur dioxide     AxesSubplot(0.01,0.563592;0.98x0.0609155)
# total sulfur dioxide    AxesSubplot(0.01,0.490493;0.98x0.0609155)
# density                 AxesSubplot(0.01,0.417394;0.98x0.0609155)
# pH                      AxesSubplot(0.01,0.344296;0.98x0.0609155)
# sulphates               AxesSubplot(0.01,0.271197;0.98x0.0609155)
# alcohol                 AxesSubplot(0.01,0.198099;0.98x0.0609155)
# quality                    AxesSubplot(0.01,0.125;0.98x0.0609155)
# dtype: object

# %% [markdown]
# #### Conclusion:
# - There are 4898 rows and 12 variables
# - All the variables are numerical
# - All the variables are non categorical
# - There are no null value persent
# - There are 937 duplicate rows

# %% [markdown]
# ## Cleaning the data

# %%
# Removing the duplicate features 
df.si
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# Drop the duplicate rows
df = df.drop_duplicates(keep='first')
df.shape
# Out:
# (3961, 12)

# %% [markdown]
# The variable have so many outliers, so its not right to consider those extreme values as anomaly. So, here we ignoring them. Thus, the data is cleaned. There is zero no null value, no duplicates value, and ever

# %% [markdown]
# # Finding the relation between variables and analyzing the variables

# %%
# Plot density function 
df.plot(kind = 'kde', figsize  = (10,20),subplots = True, layout  = (12,1),sharex = False)
# Out:
# array([[<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
# 
corr = df.corr()


plt.figure(figsize=(20,20))
# sns.heatmap(corr, vmax=1, vmin=-1, center=0,
# 			linewidth=.5,square=True, annot = True,
#             annot_kws = {'size':8},fmt='.1f', cmap='BrBG_r', ax=ax1,  # ax: use this when using subplot
#             cbar_kws = dict(use_gridspec=False,location="top", shrink=0.9)) # cbar_kws: for positioning cbar and "shrink" for reducing cbar size

sns.heatmap(corr, xticklabels= corr.columns, yticklabels = corr.columns, annot = True, annot_kws = {'size':20})

plt.title('Correlation')
plt.show()

# %%
# Highly coorelation heatmap
plt.figure(figsize=(20,20))
sns.heatmap(corr[(corr > 0.5) | (corr < -0.5) ], xticklabels= corr.columns, yticklabels = corr.columns, annot = True, annot_kws = {'size':20})
plt.title('Correlation greater than 0.5')
# Out:
# Text(0.5, 1.0, 'Correlation greater than 0.5')

# %%
# Plot the pair plot
sns.pairplot(df)

# %%
sns.relplot(x ='density', y = 'sulphates', hue = 'quality', data = df)

# %%
sns.displot(df['fixed acidity'], kde=True)

# %%
sns.catplot(x = 'fixed acidity', kind  = 'box', data = df)

# %% [markdown]
# #### Conclusion
# - The density is high positively correlated to the residual sugar and total sulfur dioxide.
# - The density is high negatively correlated to the alcohol.
# - Total sulfur dioxide is very correlated to free sulfur dioxide.
